# %%
import os
import pandas as pd
from newsapi import NewsApiClient
# %matplotlib inline

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
# Create the Facebook Libra sentiment scores DataFrame

def sentiment_dataframe(articles):
    sentiments = []

    for article in articles["articles"]:
        try:
            sentiment = analyzer.polarity_scores(article["content"])
      
            sentiments.append({
                "text": article["content"],
                "compound": sentiment["compound"],
                "positive": sentiment["pos"],
                "negative": sentiment["neg"],
                "neutral": sentiment["neu"]
            
            })
        
        except AttributeError:
            pass
    
    # Create DataFrame
    df = pd.DataFrame(sentiments)
    return df

# %% [markdown]
# # News Headlines Sentiment
#
# Use the news api to pull the latest news articles for bitcoin and ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Read your api key environment variable
api_key = os.getenv("NEWS_API_KEY")

# %%
# Create a newsapi client
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
bit_articles = newsapi.get_everything(q="bitcoin", language="en", sort_by='relevancy')

print(f"Total articles about Bitcoin: {bit_articles['totalResults']}")
# Out:
# Total articles about Bitcoin: 4090

# %%
# Fetch the Ethereum news articles
eth_articles = newsapi.get_everything(q="ethereum", language="en", sort_by='relevancy')

print(f"Total articles about Ethereum: {eth_articles['totalResults']}")
# Out:
# Total articles about Ethereum: 1096

# %%
# Create the Bitcoin sentiment scores DataFrame
bitcoin_df = sentiment_dataframe(bit_articles)
bitcoin_df
# Out:
#     compound  negative  neutral  positive  \
# 0    -0.6486     0.139    0.817     0.044
# 1    -0.7845     0.154    0.846     0.000
# 2     0.0258     0.080    0.859     0.061
# 3     0.5070     0.000    0.933     0.067
# 4    -0.0418     0.086    0.835     0.079
# 5     0.5070     0.000    0.933     0.067
# 6     0.5070     0.000    0.932     0.068
# 7     0.5070     0.000    0.931     0.069
# 8     0.5070     0.000    0.932     0.068
# 9     0.5530     0.000    0.926     0.074
# 10    0.5070     0.000    0.932     0.068
# 11    0.5070     0.000    0.932     0.068
# 12    0.6879     0.000    0.883     0.117
# 13    0.2911     0.042    0.893     0.065
# 14    0.5070     0.000    0.932     0.068
# 15    0.5070     0.000    0.932     0.068
# 16    0.6879     0.000    0.883     0.117
# 17    0.5070     0.000    0.933     0.067
# 18    0.5070     0.000    0.933     0.067
# 19    0.5070     0.000    0.932     0.068
#
#                                                  text
# 0   Since its inception in 2009, Bitcoin has made ...
# 1   New allegations against a bitcoin developer sp...
# 2   Federal authorities in the U.S. have unsealed ...
# 3   Our robot colleague Satoshi Nakaboto writes ab...
# 4   The Fine Print: The following comments are own...
# 5   Our robot colleague Satoshi Nakaboto writes ab...
# 6   Our robot colleague Satoshi Nakaboto writes ab...
# 7   Our robot colleague Satoshi Nakaboto writes ab...
# 8   Our robot colleague Satoshi Nakaboto writes ab...
# 9   Our robot colleague Satoshi Nakaboto writes ab...
# 10  Our robot colleague Satoshi Nakaboto writes ab...
# 11  Our robot colleague Satoshi Nakaboto writes ab...
# 12  Our robot colleague Satoshi Nakaboto writes ab...
# 13  Our robot colleague Satoshi Nakaboto writes ab...
# 14  Our robot colleague Satoshi Nakaboto writes ab...
# 15  Our robot colleague Satoshi Nakaboto writes ab...
# 16  Our robot colleague Satoshi Nakaboto writes ab...
# 17  Our robot colleague Satoshi Nakaboto writes ab...
# 18  Our robot colleague Satoshi Nakaboto writes ab...
# 19  Our robot colleague Satoshi Nakaboto writes ab...

# %%
# Create the ethereum sentiment scores DataFrame
ethereum_df = sentiment_dataframe(eth_articles)
ethereum_df
# Out:
#     compound  negative  neutral  positive  \
# 0     0.3818     0.000    0.933     0.067
# 1     0.1901     0.000    0.956     0.044
# 2     0.4019     0.000    0.932     0.068
# 3     0.1027     0.054    0.882     0.063
# 4     0.2500     0.033    0.911     0.056
# 5     0.0000     0.000    1.000     0.000
# 6    -0.5095     0.082    0.886     0.032
# 7    -0.8232     0.210    0.735     0.055
# 8     0.5781     0.030    0.838     0.132
# 9     0.0258     0.000    0.973     0.027
# 10    0.1779     0.103    0.758     0.139
# 11    0.2960     0.043    0.837     0.120
# 12    0.0000     0.000    1.000     0.000
# 13   -0.0772     0.048    0.911     0.041
# 14    0.3400     0.000    0.941     0.059
# 15    0.0516     0.064    0.847     0.089
# 16   -0.4939     0.088    0.912     0.000
# 17    0.7311     0.000    0.870     0.130
# 18   -0.1341     0.118    0.774     0.108
#
#                                                  text
# 0   IKEA Iceland has used Ethereum ETHtechnology t...
# 1   Blockchains like Ethereums are often pitched a...
# 2   TLDR: The Complete Blockchain and Ethereum Pro...
# 3   Further to its previous blockchain exploits, t...
# 4   Australias Perth Mint, one of the worlds large...
# 5   Announced at Ethereum Foundation's Devcon 5 co...
# 6   The total transactional volume of blockchain a...
# 7   MakerDAO, the decentralized organization that ...
# 8   Good morning Forkers, you know what time it is...
# 9   The central bank of Venezuela is reportedly lo...
# 10  The firm behind blockchain-powered cloud compu...
# 11  Controversial USD-backed stablecoin Tether is ...
# 12  Vodafone is running an augmented reality (AR) ...
# 13  UK police are set to auction around $662,000 (...
# 14  UK police raised £300,000 ($369,000) through t...
# 15  French tobacconists are getting another chance...
# 16  2 with 2 posters participating\r\nFacebook's e...
# 17  If theres one person whose intellectual proper...
# 18  Cryptocurrency giveaway scams are nothing new....

# %%
# Describe the Bitcoin Sentiment
bitcoin_df.describe()
# Out:
#         compound   negative    neutral   positive
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.342740   0.025050   0.906450   0.068500
# std     0.404623   0.049229   0.038843   0.023189
# min    -0.784500   0.000000   0.817000   0.000000
# 25%     0.453025   0.000000   0.883000   0.067000
# 50%     0.507000   0.000000   0.932000   0.068000
# 75%     0.507000   0.010500   0.932000   0.068250
# max     0.687900   0.154000   0.933000   0.117000

# %%
# Describe the Ethereum Sentiment
ethereum_df.describe()
# Out:
#         compound   negative    neutral   positive
# count  19.000000  19.000000  19.000000  19.000000
# mean    0.078374   0.045947   0.889263   0.064737
# std     0.380920   0.055848   0.076653   0.044782
# min    -0.823200   0.000000   0.735000   0.000000
# 25%    -0.038600   0.000000   0.842500   0.036500
# 50%     0.102700   0.033000   0.911000   0.059000
# 75%     0.318000   0.073000   0.937000   0.098500
# max     0.731100   0.210000   1.000000   0.139000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# #### A: Bitcoin (.07 vs .06)
#
# Q: Which coin had the highest compound score?
#
# #### A: Ethereum (.73 vs .69)
#
# Q. Which coin had the highest positive score?
#
# #### A: Ethereum (.14 vs .12)

# %% [markdown]
# ---

# %% [markdown]
# # Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word
# 2. Remove Punctuation
# 3. Remove Stopwords

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Expand the default stop words list if necessary
sw = set(stopwords.words('english'))
sw_addon = {'char', 'chars', 'fucking'}
regex = re.compile("[^a-zA-Z ]")
lemmatizer = WordNetLemmatizer()

# %%
bitcoin_df.head()
# Out:
#    compound  negative  neutral  positive  \
# 0    0.2263     0.000    0.960     0.040
# 1   -0.6486     0.139    0.817     0.044
# 2   -0.7845     0.154    0.846     0.000
# 3   -0.4767     0.069    0.931     0.000
# 4    0.0258     0.080    0.859     0.061
#
#                                                 text
# 0  At least that's the idea. While it's not as in...
# 1  Since its inception in 2009, Bitcoin has made ...
# 2  New allegations against a bitcoin developer sp...
# 3  Say it with me: Bitcoin is not anonymous. \r\n...
# 4  Federal authorities in the U.S. have unsealed ...

# %%
bit_text = ""
for article in bit_articles["articles"]:
    bit_text = bit_text + " " + article["content"]

# %%
eth_text = ""
for article in eth_articles["articles"]:
    try:
        eth_text = eth_text + " " + article["content"]        
    except TypeError:
        pass

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    tokens = []
    re_clean = regex.sub('', text)
    tokens = word_tokenize(re_clean)
    tokens = [word.lower() for word in tokens if word.lower() not in sw.union(sw_addon)]
    tokens = [lemmatizer.lemmatize(word) for word in tokens]
    
    return tokens

# %%
# Create a new tokens column for bitcoin

bitcoin_df["tokens"] = bitcoin_df["text"].apply(lambda x: tokenizer(str(x)))

bitcoin_df
# Out:
#     compound  negative  neutral  positive  \
# 0    -0.6486     0.139    0.817     0.044
# 1    -0.7845     0.154    0.846     0.000
# 2     0.0258     0.080    0.859     0.061
# 3     0.5070     0.000    0.933     0.067
# 4    -0.0418     0.086    0.835     0.079
# 5     0.5070     0.000    0.933     0.067
# 6     0.5070     0.000    0.932     0.068
# 7     0.5070     0.000    0.931     0.069
# 8     0.5070     0.000    0.932     0.068
# 9     0.5530     0.000    0.926     0.074
# 10    0.5070     0.000    0.932     0.068
# 11    0.5070     0.000    0.932     0.068
# 12    0.6879     0.000    0.883     0.117
# 13    0.2911     0.042    0.893     0.065
# 14    0.5070     0.000    0.932     0.068
# 15    0.5070     0.000    0.932     0.068
# 16    0.6879     0.000    0.883     0.117
# 17    0.5070     0.000    0.933     0.067
# 18    0.5070     0.000    0.933     0.067
# 19    0.5070     0.000    0.932     0.068
#
#                                                  text  \
# 0   Since its inception in 2009, Bitcoin has made ...
# 1   New allegations against a bitcoin developer sp...
# 2   Federal authorities in the U.S. have unsealed ...
# 3   Our robot colleague Satoshi Nakaboto writes ab...
# 4   The Fine Print: The following comments are own...
# 5   Our robot colleague Satoshi Nakaboto writes ab...
# 6   Our robot colleague Satoshi Nakaboto writes ab...
# 7   Our robot colleague Satoshi Nakaboto writes ab...
# 8   Our robot colleague Satoshi Nakaboto writes ab...
# 9   Our robot colleague Satoshi Nakaboto writes ab...
# 10  Our robot colleague Satoshi Nakaboto writes ab...
# 11  Our robot colleague Satoshi Nakaboto writes ab...
# 12  Our robot colleague Satoshi Nakaboto writes ab...
# 13  Our robot colleague Satoshi Nakaboto writes ab...
# 14  Our robot colleague Satoshi Nakaboto writes ab...
# 15  Our robot colleague Satoshi Nakaboto writes ab...
# 16  Our robot colleague Satoshi Nakaboto writes ab...
# 17  Our robot colleague Satoshi Nakaboto writes ab...
# 18  Our robot colleague Satoshi Nakaboto writes ab...
# 19  Our robot colleague Satoshi Nakaboto writes ab...
#
#                                                tokens
# 0   [since, inception, bitcoin, made, ruined, fort...
# 1   [new, allegation, bitcoin, developer, spurred,...
# 2   [federal, authority, u, unsealed, charge, sout...
# 3   [robot, colleague, satoshi, nakaboto, writes, ...
# 4   [fine, print, following, comment, owned, whoev...
# 5   [robot, colleague, satoshi, nakaboto, writes, ...
# 6   [robot, colleague, satoshi, nakaboto, writes, ...
# 7   [robot, colleague, satoshi, nakaboto, writes, ...
# 8   [robot, colleague, satoshi, nakaboto, writes, ...
# 9   [robot, colleague, satoshi, nakaboto, writes, ...
# 10  [robot, colleague, satoshi, nakaboto, writes, ...
# 11  [robot, colleague, satoshi, nakaboto, writes, ...
# 12  [robot, colleague, satoshi, nakaboto, writes, ...
# 13  [robot, colleague, satoshi, nakaboto, writes, ...
# 14  [robot, colleague, satoshi, nakaboto, writes, ...
# 15  [robot, colleague, satoshi, nakaboto, writes, ...
# 16  [robot, colleague, satoshi, nakaboto, writes, ...
# 17  [robot, colleague, satoshi, nakaboto, writes, ...
# 18  [robot, colleague, satoshi, nakaboto, writes, ...
# 19  [robot, colleague, satoshi, nakaboto, writes, ...

# %%
# Create a new tokens column for ethereum
ethereum_df["tokens"] = ethereum_df["text"].apply(lambda x: tokenizer(str(x)))

ethereum_df
# Out:
#     compound  negative  neutral  positive  \
# 0     0.3818     0.000    0.933     0.067
# 1     0.1901     0.000    0.956     0.044
# 2     0.4019     0.000    0.932     0.068
# 3     0.1027     0.054    0.882     0.063
# 4     0.2500     0.033    0.911     0.056
# 5     0.0000     0.000    1.000     0.000
# 6    -0.5095     0.082    0.886     0.032
# 7    -0.8232     0.210    0.735     0.055
# 8     0.5781     0.030    0.838     0.132
# 9     0.0258     0.000    0.973     0.027
# 10    0.1779     0.103    0.758     0.139
# 11    0.2960     0.043    0.837     0.120
# 12    0.0000     0.000    1.000     0.000
# 13   -0.0772     0.048    0.911     0.041
# 14    0.3400     0.000    0.941     0.059
# 15    0.0516     0.064    0.847     0.089
# 16   -0.4939     0.088    0.912     0.000
# 17    0.7311     0.000    0.870     0.130
# 18   -0.1341     0.118    0.774     0.108
#
#                                                  text  \
# 0   IKEA Iceland has used Ethereum ETHtechnology t...
# 1   Blockchains like Ethereums are often pitched a...
# 2   TLDR: The Complete Blockchain and Ethereum Pro...
# 3   Further to its previous blockchain exploits, t...
# 4   Australias Perth Mint, one of the worlds large...
# 5   Announced at Ethereum Foundation's Devcon 5 co...
# 6   The total transactional volume of blockchain a...
# 7   MakerDAO, the decentralized organization that ...
# 8   Good morning Forkers, you know what time it is...
# 9   The central bank of Venezuela is reportedly lo...
# 10  The firm behind blockchain-powered cloud compu...
# 11  Controversial USD-backed stablecoin Tether is ...
# 12  Vodafone is running an augmented reality (AR) ...
# 13  UK police are set to auction around $662,000 (...
# 14  UK police raised £300,000 ($369,000) through t...
# 15  French tobacconists are getting another chance...
# 16  2 with 2 posters participating\r\nFacebook's e...
# 17  If theres one person whose intellectual proper...
# 18  Cryptocurrency giveaway scams are nothing new....
#
#                                                tokens
# 0   [ikea, iceland, used, ethereum, ethtechnology,...
# 1   [blockchains, like, ethereums, often, pitched,...
# 2   [tldr, complete, blockchain, ethereum, program...
# 3   [previous, blockchain, exploit, united, nation...
# 4   [australia, perth, mint, one, world, largest, ...
# 5   [announced, ethereum, foundation, devcon, conf...
# 6   [total, transactional, volume, blockchain, app...
# 7   [makerdao, decentralized, organization, run, e...
# 8   [good, morning, forkers, know, time, moonday, ...
# 9   [central, bank, venezuela, reportedly, looking...
# 10  [firm, behind, blockchainpowered, cloud, compu...
# 11  [controversial, usdbacked, stablecoin, tether,...
# 12  [vodafone, running, anaugmented, reality, ar, ...
# 13  [uk, police, set, auction, around, worth, crim...
# 14  [uk, police, raised, auction, criminallyseized...
# 15  [french, tobacconist, getting, another, chance...
# 16  [poster, participatingfacebooks, embattled, li...
# 17  [there, one, person, whose, intellectual, prop...
# 18  [cryptocurrency, giveaway, scam, nothing, new,...

# %% [markdown]
# ---

# %% [markdown]
# # NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
bit_list = []
bit_list = tokenizer(bit_text)
bit_bigrams = Counter(ngrams(bit_list, n=2))
dict(bit_bigrams.most_common(10))
# Out:
# {('satoshi', 'nakaboto'): 32,
#  ('robot', 'colleague'): 16,
#  ('colleague', 'satoshi'): 16,
#  ('nakaboto', 'writes'): 16,
#  ('writes', 'bitcoin'): 16,
#  ('bitcoin', 'btc'): 16,
#  ('btc', 'every'): 16,
#  ('every', 'daywelcome'): 16,
#  ('daywelcome', 'another'): 16,
#  ('another', 'edition'): 16}

# %%
# Generate the Ethereum N-grams where N=2
eth_list = []
eth_list = tokenizer(eth_text)
eth_bigrams = Counter(ngrams(eth_list, n=2))
dict(eth_bigrams.most_common(10))
# Out:
# {('uk', 'police'): 3,
#  ('bitcoin', 'btc'): 3,
#  ('perth', 'mint'): 2,
#  ('ethereum', 'eth'): 2,
#  ('hard', 'fork'): 2,
#  ('security', 'law'): 2,
#  ('criminallyseized', 'bitcoin'): 2,
#  ('ikea', 'iceland'): 1,
#  ('iceland', 'used'): 1,
#  ('used', 'ethereum'): 1}

# %%
# Use the token_count function to generate the top 10 words from each coin
def token_count(tokens, N=10):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Get the top 10 words for Bitcoin

token_count(bit_list)
# Out:
# [('bitcoin', 51),
#  ('satoshi', 33),
#  ('nakaboto', 32),
#  ('robot', 16),
#  ('colleague', 16),
#  ('writes', 16),
#  ('btc', 16),
#  ('every', 16),
#  ('daywelcome', 16),
#  ('another', 16)]

# %%
# Get the top 10 words for Ethereum

token_count(eth_list)
# Out:
# [('ethereum', 6),
#  ('blockchain', 5),
#  ('cryptocurrency', 5),
#  ('bitcoin', 5),
#  ('auction', 5),
#  ('security', 4),
#  ('cryptocurrencies', 3),
#  ('con', 3),
#  ('earlier', 3),
#  ('today', 3)]

# %% [markdown]
# # Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Word Cloud Generation Function
def word_cloud(list, topic):
    bit_cloud = ' '.join(list)
    wc = WordCloud(background_color='white').generate(bit_cloud)
    plt.axis('off')
    plt.title(f"{topic} Word Cloud", fontsize=50, fontweight='bold')
    plt.imshow(wc, interpolation='bilinear')
    return

# %%
# Generate the Bitcoin word cloud
word_cloud(bit_list, "Bitcoin")

# %%
# Generate the Ethereum word cloud
word_cloud(eth_list, "Ethereum")

# %% [markdown]
# # Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both coins and visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Optional - download a language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ## Bitcoin NER

# %%
# Concatenate all of the bitcoin text together
bit_text
# Out:
# ' Since its inception in 2009, Bitcoin has made and ruined fortunes, helped sell fentanyl and books about cryptocurrency, withstood literally millions of jokes and just as many predictions of imminent collapse, andthrough a process opaque to most people, myself… [+10529 chars] New allegations against a bitcoin developer spurred a deposition from Jacob Appelbaum\r\nPhoto by Ingo Wagner / Getty Images\r\nIn the summer of 2016, a flood of abuse allegations came out against celebrity Tor developer Jacob Appelbaum, a shocking blow to one of… [+6852 chars] Federal authorities in the U.S. have unsealed charges against the South Korean operator of a child porn ring thats been billed as the worlds largest dark web child porn marketplace. The child porn site, known as Welcome to Video, charged some users in Bitcoin… [+2092 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Aristotle used to say: Time to learn s… [+3116 chars] The Fine Print: The following comments are owned by whoever posted them. We are not responsible for them in any way. Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Rousseau used to say: Lets get this br… [+2873 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Satoshi Nakamoto used to say: The long… [+3081 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Aristotle used to say: Your imaginatio… [+2947 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Baudriallard used to say: Bobs your un… [+2981 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Nietzsche used to say: Time is money!\r… [+2895 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Baudriallard used to say: Lets get thi… [+2975 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Nightingale used to say: Time is money… [+2936 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Habermass used to say: Yolo!\r\nBitcoin … [+2675 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As de Beauvoir used to say: Buy low, sell… [+2883 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Baudriallard used to say: Time is mone… [+3352 chars] O ...

# %%
# Run the NER processor on all of the text
bit_doc = nlp(bit_text)

# Add a title to the document

# %%
# Render the visualization
displacy.render(bit_doc, style='ent')
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr"> Since its inception in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     2009
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  has made and ruined fortunes, helped sell fentanyl and books about cryptocurrency, withstood literally
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     millions
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of jokes and just as many predictions of imminent collapse, andthrough a process opaque to most people, myself… [
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     +10529
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  chars] New allegations against a bitcoin developer spurred a deposition from
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Jacob Appelbaum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Photo by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Ingo Wagner / Getty Images
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>In
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the summer of 2016
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , a flood of abuse allegations came out against celebrity
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Tor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  developer
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Jacob Appelbaum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , a shocking blow to one of… [+6852 chars] Federal authorities in the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  have unsealed charges against the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     South Korean
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  operator of a child porn ring thats been billed as the worlds largest dark web child porn marketplace. The child porn site, known as
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Welcome
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  to
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Video
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# , charged some users in
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# … [+2092 chars] Our robot colleague
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Satoshi Nakaboto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  writes about
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Bitcoin BTC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Welcome to another edition of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , where I,
# <mark

# %%
# List all Entities
for ent in bit_doc.ents:
    print(ent.text, ent.label_)
# Out:
# 2009 DATE
# Bitcoin PERSON
# millions CARDINAL
# +10529 NORP
# Jacob Appelbaum PERSON
# Ingo Wagner / Getty Images ORG
# the summer of 2016 DATE
# Tor ORG
# Jacob Appelbaum PERSON
# U.S. GPE
# South Korean NORP
# Welcome FAC
# Video NORP
# Bitcoin PERSON
# Satoshi Nakaboto PERSON
# Bitcoin BTC PERSON
# Bitcoin PERSON
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin PERSON
# the past 24 hours TIME
# Aristotle PERSON
# The Fine Print ORG
# Satoshi Nakaboto PERSON
# Bitcoin BTC PERSON
# Bitcoin PERSON
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin PERSON
# the past 24 hours TIME
# Rousseau PERSON
# Satoshi Nakaboto PERSON
# Bitcoin BTC PERSON
# Bitcoin PERSON
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin PERSON
# the past 24 hours TIME
# Satoshi Nakamoto PERSON
# Satoshi Nakaboto PERSON
# Bitcoin BTC PERSON
# Bitcoin PERSON
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin PERSON
# the past 24 hours TIME
# Aristotle PERSON
# Satoshi Nakaboto PERSON
# Bitcoin BTC PERSON
# Bitcoin PERSON
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin PERSON
# the past 24 hours TIME
# Baudriallard PERSON
# +2981 ORG
# Satoshi Nakaboto PERSON
# Bitcoin BTC PERSON
# Bitcoin PERSON
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin PERSON
# the past 24 hours TIME
# Nietzsche PERSON
# Time ORG
# Satoshi Nakaboto PERSON
# Bitcoin BTC PERSON
# Bitcoin PERSON
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin PERSON
# the past 24 hours TIME
# Baudriallard PERSON
# Satoshi Nakaboto PERSON
# Bitcoin BTC PERSON
# Bitcoin PERSON
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin PERSON
# the past 24 hours TIME
# Nightingale PERSON
# Time ORG
# Satoshi Nakaboto PERSON
# Bitcoin BTC PERSON
# Bitcoin PERSON
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin PERSON
# the past 24 hours TIME
# Yolo PERSON
# Bitcoin PERSON
# Satoshi Nakaboto PERSON
# Bitcoin BTC PERSON
# Bitcoin PERSON
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin PERSON
# the past 24 hours TIME
# de Beauvoir PERSON
# Satoshi Nakaboto PERSON
# Bitcoin BTC PERSON
# Bitcoin PERSON
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin PERSON
# the past 24 hours TIME
# Baudriallard PERSON
# Time ORG
# Satoshi Nakaboto PERSON
# Bitcoin BTC PERSON
# Bitcoin PERSON
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin PERSON
# the past 24 hours TIME
# Faraday DATE
# Satoshi Nakaboto PERSON
# Bitcoin BTC PERSON
# Bitcoin PERSON
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin PERSON
# the past 24 hours TIME
# Schopenhauer PERSON
# Yolo PERSON
# Bitco ORG
# +2872 NORP
# Satoshi Nakaboto PERSON
# Bitcoin BTC PERSON
# Bitcoin PERSON
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin PERSON
# the past 24 hours TIME
# Nikola Tesla PERSON
# Satoshi Nakaboto PERSON
# Bitcoin BTC PERSON
# Bitcoin PERSON
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin PERSON
# the past 24 hours TIME
# Hannah Arendt PERSON
# Satoshi Nakaboto PERSON
# Bitcoin BTC PERSON
# Bitcoin PERSON
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin PERSON
# the past 24 hours TIME

# %% [markdown]
# ---

# %% [markdown]
# ## Ethereum NER

# %%
# Concatenate all of the bitcoin text together
eth_text
# Out:
# ' IKEA Iceland has used Ethereum ETHtechnology to settle an invoice with a local retailer, accepting payment\xa0in blockchainified\xa0digital cash.\r\nSupply chain payments firm Tradeshift facilitated the transfer using an Ethereum-based version of the Icelandic\xa0króna … [+1062 chars] Blockchains like Ethereums are often pitched as self-sovereign money networks that operate independently of states, financial institutions, and corporations\xa0 but recent research shows this might not be reality.\r\nAs it turns out, its really centralized cloud s… [+3927 chars] TLDR: The Complete Blockchain and Ethereum Programming Bundle help you understand cryptocurrencies and its root technology for under $30.\r\nEverybodys got an opinion about cryptocurrencies and their future place in international finance. As leading cryptos con… [+1413 chars] Further to its previous blockchain exploits, the United Nations Childrens Fund, more commonly known as UNICEF, is now taking donations in cryptocurrency.\r\nAccording to an announcement earlier today, UNICEF is setting up a cryptocurrency fund so that it can re… [+2245 chars] Australias Perth Mint, one of the worlds largest refineries, is today launching a gold-backed Ethereum ETH token guaranteed by the government of Western Australia.\r\nMarketing materials shared with Hard Fork claim the Perth Mint Gold Token (PMGT) is the first … [+2098 chars] Announced at Ethereum Foundation\'s Devcon 5 conference in Osaka, Japan, OpenLibra is described as an "open platform for financial inclusion," with a telling tagline: "Not run by Facebook." OpenLibra aims to be compatible with Libra in a technical sense, meani… [+691 chars] The total transactional volume of blockchain apps (dapps) across the six major dapp-centric networks hit just $2.03 billion last quarter, down by nearly 40 percent.\r\nMore troubling, just 148 dapps launched in Q3 of this year. Thats less than the monthlyaverag… [+2746 chars] MakerDAO, the decentralized organization that runs on Ethereum, ETH has disclosed an enormously dangerous security flaw that couldve allowed an attacker to steal\xa0all of the\xa0collateral\xa0powering its Dai\xa0stablecoin with a single transaction.\r\nThe bug, if exploit… [+2233 chars] Good morning Forkers, you know what time it is. Its Moonday Mornings, Hard Forks wrap-up of the weekends top cryptocurrency and blockchain headlines you cant afford to miss.\r\nCheck it out.\r\n1. The Ukrainian government is allegedly preparing plans to legalize … [+1982 chars] The central bank of Venezuela is reportedly looking into whether it can store cryptocurrencies in its coffers, Bloomberg reports citing four anonymous individuals close to the matter.\r\nAccording to the report the banks investigation follows a request by Petro… [+1633 chars] The firm behind blockchain-powered cloud computing service EOS EOS must pay $24 million for violating US securities law with its initial coin offering (ICO).\r\nBlock.one did not register its ICO as a securities offering pursuant to the federal securities laws,… [+1878 chars] Controversial USD-backed stablecoin Tether is now the worlds fourth biggest cryptocurrency, only surpassed by Bitcoin, Ethereum, and Ripple.\r\nTether, which is actually only 74-percent backed by cash and other assets, garnered a higher share of the market afte… [+852 chars] Vodafone is running an\xa0augmented reality (AR) game across London as part of a promotional Apple giveaway, and its powered by blockchain technology.\r\nThe game, called Find Unlimited, requires players find and interact with Vatoms, unique,\xa0non-fungible tokens (… [+1375 chars] UK police are set to auction around $662,000 (£500,000) worth of criminally-seized Bitcoin BTC this week, a reported first for the nation.\r\nAnnounced earlier this month, Irish auction house Wilsons Auctions has set no reserves, and will sell it all to the hig… [+1599 chars] UK police raised £300,000 ($369,000) through the auction of criminally-seized Bitcoin BTC a ...

# %%
# Run the NER processor on all of the text
eth_doc = nlp(eth_text)
# Add a title to the document

# %%
# Render the visualization
displacy.render(eth_doc, style='ent')
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr"> IKEA
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Iceland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has used
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Ethereum ETHtechnology
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>Supply chain payments firm
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Tradeshift
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  facilitated the transfer using an
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# -based version of the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Icelandic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# </br>As it turns out, its really centralized cloud s… [+3927 chars] TLDR:
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     The Complete Blockchain and Ethereum Programming Bundle
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  help you understand cryptocurrencies and its root technology for under $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     30
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Everybodys
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  got an opinion about cryptocurrencies and their future place in international finance. As leading cryptos con… [+1413 chars] Further to its previous blockchain exploits,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the United Nations Childrens Fund
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , more commonly known as
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     UNICEF
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>According to an announcement earlier today,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     UNICEF
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is setting up a cryptocurrency fund so that it can re… [+2245 chars]
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Australias Perth Mint
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of the worlds largest refineries, is
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  launching a gold-backed
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Ethereum ETH
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  token guaranteed by the government of
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Western Australia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# </br>Marketing materials shared with
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Hard Fork
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  claim
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the Perth Mint Gold Token
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </ma

# %%
# List all Entities
for ent in eth_doc.ents:
    print(ent.text, ent.label_)
# Out:
# Iceland ORG
# Ethereum ETHtechnology ORG
# Tradeshift ORG
# Ethereum PRODUCT
# Icelandic NORP
# The Complete Blockchain and Ethereum Programming Bundle ORG
# 30 MONEY
# Everybodys ORG
# the United Nations Childrens Fund ORG
# UNICEF ORG
# UNICEF ORG
# Australias Perth Mint ORG
# one CARDINAL
# today DATE
# Ethereum ETH ORG
# Western Australia LOC
# Hard Fork ORG
# the Perth Mint Gold Token ORG
# first ORDINAL
# Ethereum Foundation's ORG
# Devcon 5 FAC
# Osaka GPE
# Japan GPE
# OpenLibra ORG
# Facebook ORG
# OpenLibra ORG
# Libra ORG
# six CARDINAL
# just $2.03 billion MONEY
# last quarter DATE
# nearly 40 percent PERCENT
# 148 CARDINAL
# Q3 of this year DATE
# ETH ORG
# Dai  PERSON
# Good morning Forkers WORK_OF_ART
# Moonday Mornings PERSON
# Hard Forks ORG
# 1 CARDINAL
# Ukrainian NORP
# Venezuela GPE
# Bloomberg PERSON
# four CARDINAL
# Petro PERSON
# $24 million MONEY
# US GPE
# ICO ORG
# Block.one ORG
# ICO ORG
# Controversial USD PRODUCT
# Tether ORG
# fourth ORDINAL
# Bitcoin PERSON
# Ripple ORG
# Tether ORG
# Vodafone PERSON
# London GPE
# Apple ORG
# Find Unlimited ORG
# Vatoms PRODUCT
# UK GPE
# around $662,000 MONEY
# 500,000 CARDINAL
# Bitcoin BTC PERSON
# this week DATE
# first ORDINAL
# earlier this month DATE
# Irish NORP
# UK GPE
# 300,000 MONEY
# 369,000 MONEY
# Bitcoin BTC PERSON
# this week DATE
# first ORDINAL
# UK GPE
# two CARDINAL
# Septem PERSON
# French NORP
# Bitcoin BTC PRODUCT
# earlier this year DATE
# today DATE
# 5,200 CARDINAL
# 2 CARDINAL
# 2 CARDINAL
# Facebook ORG
# Libra GPE
# Friday DATE
# four CARDINAL
# Visa PERSON
# Mastercard PERSON
# Mercado Pagowithdrew ORG
# the Libra Association ORG
# Geneva GPE
# Facebook ORG
# one CARDINAL
# Nintendo PERSON
# Roberto De Jesus Escobar Gaviria PERSON
# Pablo Escobar GPE
# Escobar Inc ORG
# Pablo GPE
# Elon Musk PERSON
# Vitalik Buterin PERSON
# just days DATE
# Bitcoin PERSON
